# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv("/content/CC GENERAL.csv")

# %%
df.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000                 0              2        1000.0
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0   201.802084        139.509787          0.000000      12
# 1  4103.032597       1072.340217          0.222222      12
# 2   622.066742        627.284787          0.000000      12
# 3     0.000000               NaN          0.000000      12
# 4   678.334763        244.791237          0.000000      12

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
#  11  CASH_ADVANCE_TRX                  8950 non-null   int64
#  12  PURCHASES_TRX                     8950 non-null   int64
#  13  CREDIT_LIMIT                      8949 non-null   float64
#  14  PAYMENTS                          8950 non-null   float64
#  15  MINIMUM_PAYMENTS                  8637 non-null   float64
#  16  PRC_FULL_PAYMENT                  8950 non-null   float64
#  17  TENURE                            8950 non-null   int64
# dtypes: float64(14), int64(3), object(1)
# memory usage: 1.2+ MB

# %%
df.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# 25%                  0.000000      0.000000             0.083333
# 50%                 89.000000      0.000000             0.500000
# 75%                468.637500   1113.821139             0.916667
# max              22500.000000  47137.211760             1.000000
#
#        ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# count                 8950.000000                       8950.000000
# mean                     0.202458                          0.364437
# std                      0.298336                          0.397448
# min                      0.000000                          0.000000
# 25%                      0.000000                          0.000000
# 50%                      0.083333                          0.166667
# 75%                      0.300000                          0.750000
# max                      1.000000                          1.000000
#
#        CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# count             8950.000000       8950.000000    8950.000000   8949.000000
# mean                 0.135144          3.248827      14.709832   4494.449450
# std                  0.200121          6.824647      24.857649   3638.815725
# min                  0.000000          0.000000       0.000000     50.000000
# 25%                  0.000000          0.000000       1.000000   1600.000000
# 50%                  0.000000          0.000000       7.000000   3000.000000
# 75%                  0.222222          4.000000      17.000000   6500.000000
# max                  1.500000        123.000000     358.000000  30000.000000
#
#            PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT       TENURE
# count   8950.000000       8637.000000       8950.000000  8950.000000
# mean    1733.143852        864.206542          0.153715    11.517318
# std     2895.063757       2372.446607          0.292499     1.338331
# min        0.000000          0.019163          0.000000     6.000000
# 25%      383.276166        169.123707          0.000000    12.000000
# 50%      856.901546        312.343947          0.000000    12.000000
# 75%     1901.134317        825.485459          0.142857    12.000000
# max    50721.483360      76406.207520          1.000000    12.000000

# %% [markdown]
# Mean Balance: 1565$
#
# Mean Purchase Made By the Customer Using the Credit Card: 1000$
#
# The Highest OneOff Purchase Done By User: 40761$
#
# Average Purchase Frequency Made By the User Using Credit Card: 0.49(Moderately Frequent)
#
# Average Purchase Transactions Made By User Using Credit Card: 15
#
# Average Credit Limit: 5000$
#
# Max Credit Limit: 30000$

# %%
total=df.shape[0]
null_columns=[i for i in df.columns if df[i].isnull().sum()>0]
if null_columns==[]:
  print("No Null Values Present")
else:
  print("Null Values Present")
for i in null_columns:
  print(i,"(Null Values):",df[i].isnull().sum())
# Out:
# Null Values Present
# CREDIT_LIMIT (Null Values): 1
# MINIMUM_PAYMENTS (Null Values): 313

# %%
df["MINIMUM_PAYMENTS"] = df["MINIMUM_PAYMENTS"].fillna(df["MINIMUM_PAYMENTS"].mean())
df.isnull().sum()
# Out:
# CUST_ID                             0
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        1
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %%
df["CREDIT_LIMIT"] = df["CREDIT_LIMIT"].fillna(0)

# %%
df.drop("CUST_ID", axis=1,inplace=True)

# %%
df.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000                 0              2        1000.0
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0   201.802084        139.509787          0.000000      12
# 1  4103.032597       1072.340217          0.222222      12
# 2   622.066742        627.284787          0.000000      12
# 3     0.000000        864.206542          0.000000      12
# 4   678.334763        244.791237          0.000000      12

# %%
correlations =df.corr()
plt.subplots(figsize = (15,15))
sns.heatmap(correlations, annot = True)
# Out:
# <Axes: >

# %%
import seaborn as sns
plt.figure(figsize=(10, 50))
for i in range(len(df.columns)):
    plt.subplot(17, 1, i+1)
    sns.histplot(df[df.columns[i]], kde=True, color="b", line_kws={"color": "red", "lw": 3})
    plt.title(df.columns[i])

plt.tight_layout()
plt.show()

# %% [markdown]
# Balance Distribution : is heavily right skewed which indicates that large number of customers keep low balance and smaller group of customers keep higher balance upto 17500
#
# Balance Frequency Distribution: the distribution shows sharp peak at higher end indicating many user update thier balance frequently
#
# Purachse Frequency Distributin: the distribution shows two sharp ends the lower and higher, which shows that there are
# large number of users which rarely make payment using credit card
#
# Prc_Full_payment Distribution: Large number of users pay off very less percentage of their balance
#
# The distribution of the rest of the variables are right skewed

# %%
plt.figure(figsize=(20,5))
plt.xticks(rotation=90)
sns.boxplot(df)
# Out:
# <Axes: >

# %% [markdown]
# ONEOFF_PURCHASES and PURCHASES ARE HIGHLY CORRELATED
#
# PURCHASE_INSTALLMENT_FREQUENCY and PURCHASE_FREQUENCY ARE HIGHLY CORRELATED

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
df_scaled=scaler.fit_transform(df)

# %%
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++',n_init=10, random_state = 42)
    kmeans.fit(df_scaled)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %% [markdown]
# optimal number of clusters is 7

# %%
kmeans = KMeans(n_clusters = 7, init = 'k-means++',n_init=10, random_state = 42)
ymeans=kmeans.fit_predict(df_scaled)

# %%
cluster_centers = pd.DataFrame(data = kmeans.cluster_centers_, columns = [df.columns])
cluster_centers
# Out:
#     BALANCE BALANCE_FREQUENCY PURCHASES ONEOFF_PURCHASES  \
# 0 -0.371237          0.332046 -0.039353        -0.231758
# 1 -0.335506         -0.348076 -0.284525        -0.208973
# 2  0.003531          0.403037 -0.340965        -0.221502
# 3  0.145765          0.430720  0.973857         0.924456
# 4  1.654246          0.398136 -0.203861        -0.149620
# 5 -0.701329         -2.132409 -0.307190        -0.231071
# 6  1.502824          0.406491  7.310815         6.389959
#
#   INSTALLMENTS_PURCHASES CASH_ADVANCE PURCHASES_FREQUENCY  \
# 0               0.332557    -0.367806            0.982063
# 1              -0.288475     0.065539           -0.198735
# 2              -0.399161    -0.109985           -0.805115
# 3               0.604267    -0.307665            1.101493
# 4              -0.207238     1.975954           -0.457360
# 5              -0.301714    -0.320269           -0.548149
# 6               5.543973     0.015522            1.072591
#
#   ONEOFF_PURCHASES_FREQUENCY PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                  -0.346297                         1.172606
# 1                  -0.272572                        -0.230755
# 2                  -0.329931                        -0.752069
# 3                   1.881096                         0.549846
# 4                  -0.189139                        -0.405848
# 5                  -0.429684                        -0.441113
# 6                   1.833619                         1.037771
#
#   CASH_ADVANCE_FREQUENCY CASH_ADVANCE_TRX PURCHASES_TRX CREDIT_LIMIT  \
# 0              -0.477250        -0.362613      0.173854    -0.275956
# 1               0.304112        -0.002216     -0.385586    -0.558676
# 2               0.075530        -0.047246     -0.462362    -0.303155
# 3              -0.407200        -0.316467      1.230209     0.722464
# 4               1.906131         1.910995     -0.240670     0.999796
# 5              -0.520666        -0.375795     -0.416379    -0.172347
# 6              -0.319186        -0.117442      4.843666     2.228806
#
#    PAYMENTS MINIMUM_PAYMENTS PRC_FULL_PAYMENT    TENURE
# 0 -0.222456        -0.030030         0.304580  0.252473
# 1 -0.390701        -0.209383         0.012899 -3.193765
# 2 -0.248906        -0.016507        -0.451966  0.272274
# 3  0.411960        -0.029410         0.471295  0.307135
# 4  0.813046         0.543964        -0.394846  0.072328
# 5 -0.191899        -0.257180         0.298615  0.202573
# 6  5.034193         1.184700         0.806631  0.331183

# %%
cluster_centers = scaler.inverse_transform(cluster_centers)
cluster_centers = pd.DataFrame(data = cluster_centers, columns = [df.columns])
cluster_centers
# Out:
#        BALANCE BALANCE_FREQUENCY     PURCHASES ONEOFF_PURCHASES  \
# 0   791.775321          0.955929    919.126309       207.766685
# 1   866.148306          0.794815    395.311749       245.585564
# 2  1571.823354          0.972747    274.726898       224.790158
# 3  1867.873391          0.979304   3083.865947      2126.845287
# 4  5007.647671          0.971586    567.652260       344.099592
# 5   104.718081          0.372123    346.889228       208.907313
# 6  4692.477130          0.973565  16622.873947     11198.460658
#
#   INSTALLMENTS_PURCHASES CASH_ADVANCE PURCHASES_FREQUENCY  \
# 0             711.795158   207.565747            0.884500
# 1             150.203132  1116.308792            0.410589
# 2              50.110993   748.227408            0.167219
# 3             957.498368   333.684253            0.932433
# 4             223.664763  5122.538298            0.306790
# 5             138.231117   307.252169            0.270352
# 6            5424.413289  1011.421719            0.920833
#
#   ONEOFF_PURCHASES_FREQUENCY PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                   0.099150                         0.830461
# 1                   0.121144                         0.272729
# 2                   0.104033                         0.065546
# 3                   0.763625                         0.582960
# 4                   0.146034                         0.203143
# 5                   0.074275                         0.189128
# 6                   0.749462                         0.776874
#
#   CASH_ADVANCE_FREQUENCY CASH_ADVANCE_TRX PURCHASES_TRX  CREDIT_LIMIT  \
# 0               0.039642         0.774256     19.031204   3489.819699
# 1               0.196000         3.233704      5.125596   2461.081081
# 2               0.150259         2.926408      3.217254   3390.850939
# 3               0.053659         1.089172     45.288217   7122.792415
# 4               0.516580        16.289967      8.727674   8131.923424
# 5               0.030954         0.684299      4.360202   3866.825730
# 6               0.071272         2.447368    135.105263  12603.947368
#
#        PAYMENTS MINIMUM_PAYMENTS PRC_FULL_PAYMENT     TENURE
# 0   1089.154086       794.223824         0.242799  11.855193
# 1    602.104087       376.247870         0.157487   7.243243
# 2   1012.585780       825.738033         0.021522  11.881690
# 3   2925.728113       795.667678         0.291560  11.928344
# 4   4086.831588      2131.891078         0.038229  11.614112
# 5   1177.615452       264.859949         0.241055  11.788413
# 6  16306.639412      3625.099437         0.389640  11.960526

# %% [markdown]
# Cluster 0: Customers with a low balance, which is updated very frequently, and who exhibit a very high purchase frequency (are active in transactions). Approximately 24% of their balance has been paid off, and they have an average tenure of 11 years.
#
# Cluster 1: Customers with a low balance, which is frequently updated, and who demonstrate a moderate purchase frequency (moderately active in transactions). Approximately 15% of their balance has been paid off, and they have an average tenure of 7 years.
#
# Cluster 2: Customers with a moderate balance, which is updated very frequently, having made fewer purchase amounts and having the least purchase frequency. Approximately 2% of their balance has been paid off, and they have an average tenure of 11 years.
#
# Cluster 3: Customers with a moderate balance, which is updated very frequently, and who exhibit a very high purchase frequency (very active in transactions). Approximately 29% of their balance has been paid off, and they have an average tenure of 11 years.
#
# Cluster 4: Customers with a high balance, which is very frequently updated, but who make very few purchase amounts relative to their balance, resulting in a low purchase frequency (not active in transactions). Approximately 3% of their balance has been paid off, and they have an average tenure of 11 years.
#
# Cluster 5: Users with the lowest balance, which are not frequently updated, and who have the lowest purchase frequency (not active in transactions). Approximately 24% of their balance has been paid off, and they have an average tenure of 11 years.
#
# Cluster 6: Customers with a high balance, which is frequently updated. They make purchases of large amounts (highest among all clusters) and make purchases very frequently. Approximately 39% of their balance has been paid off, and they have an average tenure of 11 years.

# %%
labels=kmeans.labels_
df_cluster = pd.concat([df, pd.DataFrame({'cluster':labels})], axis = 1)
df_cluster.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000                 0              2        1000.0
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE  cluster
# 0   201.802084        139.509787          0.000000      12        2
# 1  4103.032597       1072.340217          0.222222      12        4
# 2   622.066742        627.284787          0.000000      12        3
# 3     0.000000        864.206542          0.000000      12        2
# 4   678.334763        244.791237          0.000000      12        2

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 2)
df_scaled = pca.fit_transform(df_scaled)

# %%
pca_creditdf=pd.DataFrame(df_scaled,columns=["pca1","pca2"])
pca_creditdf.head()
# Out:
#        pca1      pca2
# 0 -1.682257 -1.076283
# 1 -1.138074  2.506583
# 2  0.969753 -0.383503
# 3 -0.873556  0.043204
# 4 -1.599435 -0.688390

# %%
pca_creditdf=pd.concat([pca_creditdf,pd.DataFrame({"cluster":labels})],axis=1)
pca_creditdf.head()
# Out:
#        pca1      pca2  cluster
# 0 -1.682257 -1.076283        2
# 1 -1.138074  2.506583        4
# 2  0.969753 -0.383503        3
# 3 -0.873556  0.043204        2
# 4 -1.599435 -0.688390        2

# %%
plt.figure(figsize=(10,10))
ax = sns.scatterplot(x="pca1", y="pca2", hue = "cluster", data = pca_creditdf, palette =['red','green','blue','pink','yellow','gray','purple', 'black'])
plt.show()
# Out:
# <ipython-input-223-a6ce0f9d341e>:2: UserWarning: The palette list has more values (8) than needed (7), which may not be intended.
#   ax = sns.scatterplot(x="pca1", y="pca2", hue = "cluster", data = pca_creditdf, palette =['red','green','blue','pink','yellow','gray','purple', 'black'])

# %%
df_cluster.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000                 0              2        1000.0
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE  cluster
# 0   201.802084        139.509787          0.000000      12        2
# 1  4103.032597       1072.340217          0.222222      12        4
# 2   622.066742        627.284787          0.000000      12        3
# 3     0.000000        864.206542          0.000000      12        2
# 4   678.334763        244.791237          0.000000      12        2

# %%
df_cluster.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   BALANCE                           8950 non-null   float64
#  1   BALANCE_FREQUENCY                 8950 non-null   float64
#  2   PURCHASES                         8950 non-null   float64
#  3   ONEOFF_PURCHASES                  8950 non-null   float64
#  4   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  5   CASH_ADVANCE                      8950 non-null   float64
#  6   PURCHASES_FREQUENCY               8950 non-null   float64
#  7   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  8   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  9   CASH_ADVANCE_FREQUENCY            8950 non-null   float64
#  10  CASH_ADVANCE_TRX                  8950 non-null   int64
#  11  PURCHASES_TRX                     8950 non-null   int64
#  12  CREDIT_LIMIT                      8950 non-null   float64
#  13  PAYMENTS                          8950 non-null   float64
#  14  MINIMUM_PAYMENTS                  8950 non-null   float64
#  15  PRC_FULL_PAYMENT                  8950 non-null   float64
#  16  TENURE                            8950 non-null   int64
#  17  cluster                           8950 non-null   int32
# dtypes: float64(14), int32(1), int64(3)
# memory usage: 1.2 MB

# %%
x=df_cluster.drop(["cluster"],axis=1)
y=df_cluster["cluster"]

# %%
y.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 8950 entries, 0 to 8949
# Series name: cluster
# Non-Null Count  Dtype
# --------------  -----
# 8950 non-null   int32
# dtypes: int32(1)
# memory usage: 35.1 KB

# %%
y=y.astype(str)

# %%
y.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 8950 entries, 0 to 8949
# Series name: cluster
# Non-Null Count  Dtype
# --------------  -----
# 8950 non-null   object
# dtypes: object(1)
# memory usage: 70.0+ KB

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.ensemble import RandomForestClassifier
classifier1=RandomForestClassifier()
classifier1.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
y_pred=classifier1.predict(x_test)
cm=confusion_matrix(y_test,y_pred)
print(cm)
accuracy=accuracy_score(y_test,y_pred)
print(accuracy)
# Out:
# [[389   0   8   5   0   0   0]
#  [  2 105   0   1   1   2   0]
#  [  6   0 542   4   6   0   0]
#  [ 16   0   3 237   1   2   2]
#  [  4   3   9   2 174   0   0]
#  [  4   1   1   2   0 238   0]
#  [  0   0   0   4   1   1  14]]
# 0.9491620111731843
