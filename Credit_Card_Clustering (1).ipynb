# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv("/content/CC GENERAL.csv")

# %%
df.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %%
df.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %% [markdown]
# Mean Balance: 1565$
#
# Mean Purchase Made By the Customer Using the Credit Card: 1000$
#
# The Highest OneOff Purchase Done By User: 40761$
#
# Average Purchase Frequency Made By the User Using Credit Card: 0.49(Moderately Frequent)
#
# Average Purchase Transactions Made By User Using Credit Card: 15
#
# Average Credit Limit: 5000$
#
# Max Credit Limit: 30000$

# %%
total=df.shape[0]
null_columns=[i for i in df.columns if df[i].isnull().sum()>0]
if null_columns==[]:
  print("No Null Values Present")
else:
  print("Null Values Present")
for i in null_columns:
  print(i,"(Null Values):",df[i].isnull().sum())
# Out:
# Null Values Present
# CREDIT_LIMIT (Null Values): 1
# MINIMUM_PAYMENTS (Null Values): 313

# %%
df["MINIMUM_PAYMENTS"] = df["MINIMUM_PAYMENTS"].fillna(df["MINIMUM_PAYMENTS"].mean())
df.isnull().sum()
# Out:
# CUST_ID                             0
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        1
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %%
df["CREDIT_LIMIT"] = df["CREDIT_LIMIT"].fillna(0)

# %%
df.drop("CUST_ID", axis=1,inplace=True)

# %%
df.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# ...

# %%
import seaborn as sns
correlations =df.corr()
plt.subplots(figsize = (15,15))
sns.heatmap(correlations, annot = True)
# Out:
# <Axes: >

# %% [markdown]
# ONEOFF_PURCHASES and PURCHASES ARE HIGHLY CORRELATED
#
# PURCHASE_INSTALLMENT_FREQUENCY and PURCHASE_FREQUENCY ARE HIGHLY CORRELATED

# %%
import seaborn as sns
plt.figure(figsize=(10, 50))
for i in range(len(df.columns)):
    plt.subplot(17, 1, i+1)
    sns.histplot(df[df.columns[i]], kde=True, color="b", line_kws={"color": "red", "lw": 3})
    plt.title(df.columns[i])

plt.tight_layout()
plt.show()

# %% [markdown]
# Balance Distribution : is heavily right skewed which indicates that large number of customers keep low balance and smaller group of customers keep higher balance upto 17500
#
# Balance Frequency Distribution: the distribution shows sharp peak at higher end indicating many user update thier balance frequently
#
# Purachse Frequency Distributin: the distribution shows two sharp ends the lower and higher, which shows that there are
# large number of users which rarely make payment using credit card
#
# Prc_Full_payment Distribution: Large number of users pay off very less percentage of their balance
#
# The distribution of the rest of the variables are right skewed

# %%
plt.figure(figsize=(20,5))
plt.xticks(rotation=90)
sns.boxplot(df)
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
df_scaled=scaler.fit_transform(df)

# %%
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++',n_init=10, random_state = 42)
    kmeans.fit(df_scaled)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %% [markdown]
# optimal number of clusters is 7

# %%
kmeans_1 = KMeans(n_clusters = 7, init = 'k-means++',n_init=10, random_state = 42)
ymeans=kmeans_1.fit_predict(df_scaled)

# %%
cluster_centers = pd.DataFrame(data = kmeans_1.cluster_centers_, columns = [df.columns])
cluster_centers
# Out:
#     BALANCE BALANCE_FREQUENCY PURCHASES ONEOFF_PURCHASES  \
# 0  1.430238          0.419467  6.915048         6.083034
# 1  1.666473          0.392099 -0.205327        -0.149913
# 2  0.126801          0.429730  0.939029         0.895888
# 3 -0.367555          0.330562 -0.039840        -0.234950
# 4 -0.335506         -0.348076 -0.284525        -0.208973
# 5  0.007813          0.402983 -0.343915        -0.225214
# 6 -0.701872         -2.134325 -0.306924        -0.230292
#
#   INSTALLMENTS_PURCHASES CASH_ADVANCE PURCHASES_FREQUENCY  \
# 0               5.172266     0.038778            1.090699
# 1              -0.210162     1.990753           -0.456789
# 2               0.574411    -0.309125            1.092770
# 3               0.337266    -0.368099            0.980609
# 4              -0.288475     0.065539           -0.198735
# 5              -0.399316    -0.104212           -0.810261
# 6              -0.302515    -0.323078           -0.547138
#
# ...

# %%
cluster_centers = scaler.inverse_transform(cluster_centers)
cluster_centers = pd.DataFrame(data = cluster_centers, columns = [df.columns])
cluster_centers
# Out:
#        BALANCE BALANCE_FREQUENCY     PURCHASES ONEOFF_PURCHASES  \
# 0  4541.393882          0.976638  15777.311395     10689.027791
# 1  5033.096672          0.970155    564.520447       343.613277
# 2  1828.399674          0.979070   3009.455142      2079.427650
# 3   799.439665          0.955578    918.085545       202.468866
# 4   866.148306          0.794815    395.311749       245.585564
# 5  1580.736068          0.972734    268.425678       218.628807
# 6   103.587241          0.371669    347.456361       210.199629
#
#   INSTALLMENTS_PURCHASES CASH_ADVANCE PURCHASES_FREQUENCY  \
# 0            5088.283605  1060.190695            0.928101
# 1             221.020895  5153.573564            0.307019
# 2             930.500678   330.620880            0.928932
# 3             716.053491   206.951098            0.883916
# 4             150.203132  1116.308792            0.410589
# 5              49.971063   760.334088            0.165154
# ...

# %% [markdown]
# Cluster 0: Customers with a low balance, which is updated very frequently, and who exhibit a very high purchase frequency (are active in transactions). Approximately 24% of their balance has been paid off, and they have an average tenure of 11 years.
#
# Cluster 1: Customers with a low balance, which is frequently updated, and who demonstrate a moderate purchase frequency (moderately active in transactions). Approximately 15% of their balance has been paid off, and they have an average tenure of 7 years.
#
# Cluster 2: Customers with a moderate balance, which is updated very frequently, having made fewer purchase amounts and having the least purchase frequency. Approximately 2% of their balance has been paid off, and they have an average tenure of 11 years.
#
# Cluster 3: Customers with a moderate balance, which is updated very frequently, and who exhibit a very high purchase frequency (very active in transactions). Approximately 29% of their balance has been paid off, and they have an average tenure of 11 years.
#
# Cluster 4: Customers with a high balance, which is very frequently updated, but who make very few purchase amounts relative to their balance, resulting in a low purchase frequency (not active in transactions). Approximately 3% of their balance has been paid off, and they have an average tenure of 11 years.
#
# Cluster 5: Users with the lowest balance, which are not frequently updated, and who have the lowest purchase frequency (not active in transactions). Approximately 24% of their balance has been paid off, and they have an average tenure of 11 years.
#
# Cluster 6: Customers with a high balance, which is frequently updated. They make purchases of large amounts (highest among all clusters) and make purchases very frequently. Approximately 39% of their balance has been paid off, and they have an average tenure of 11 years.

# %%
labels=kmeans_1.labels_
df_cluster = pd.concat([df, pd.DataFrame({'cluster':labels})], axis = 1)
df_cluster.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# ...

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 2)
df_scaled = pca.fit_transform(df_scaled)

# %%
pca_creditdf=pd.DataFrame(df_scaled,columns=["pca1","pca2"])
pca_creditdf.head()
# Out:
#        pca1      pca2
# 0 -1.682258 -1.076280
# 1 -1.138077  2.506588
# 2  0.969754 -0.383514
# 3 -0.873558  0.043211
# 4 -1.599436 -0.688391

# %%
pca_creditdf=pd.concat([pca_creditdf,pd.DataFrame({"cluster":labels})],axis=1)
pca_creditdf.head()
# Out:
#        pca1      pca2  cluster
# 0 -1.682258 -1.076280        5
# 1 -1.138077  2.506588        1
# 2  0.969754 -0.383514        2
# 3 -0.873558  0.043211        5
# 4 -1.599436 -0.688391        5

# %%
plt.figure(figsize=(10,10))
ax = sns.scatterplot(x="pca1", y="pca2", hue = "cluster", data = pca_creditdf, palette =['red','green','blue','pink','yellow','gray','purple', 'black'])
plt.show()
# Out:
# <ipython-input-180-a6ce0f9d341e>:2: UserWarning: The palette list has more values (8) than needed (7), which may not be intended.
#   ax = sns.scatterplot(x="pca1", y="pca2", hue = "cluster", data = pca_creditdf, palette =['red','green','blue','pink','yellow','gray','purple', 'black'])

# %%
df_cluster.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# ...

# %%
df_cluster.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   BALANCE                           8950 non-null   float64
#  1   BALANCE_FREQUENCY                 8950 non-null   float64
#  2   PURCHASES                         8950 non-null   float64
#  3   ONEOFF_PURCHASES                  8950 non-null   float64
#  4   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  5   CASH_ADVANCE                      8950 non-null   float64
#  6   PURCHASES_FREQUENCY               8950 non-null   float64
#  7   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  8   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  9   CASH_ADVANCE_FREQUENCY            8950 non-null   float64
#  10  CASH_ADVANCE_TRX                  8950 non-null   int64
# ...

# %%
x=df_cluster.drop(["cluster"],axis=1)
y=df_cluster["cluster"]

# %%
y.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 8950 entries, 0 to 8949
# Series name: cluster
# Non-Null Count  Dtype
# --------------  -----
# 8950 non-null   int32
# dtypes: int32(1)
# memory usage: 35.1 KB

# %%
y=y.astype(str)

# %%
y.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 8950 entries, 0 to 8949
# Series name: cluster
# Non-Null Count  Dtype
# --------------  -----
# 8950 non-null   object
# dtypes: object(1)
# memory usage: 70.0+ KB

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.ensemble import RandomForestClassifier
classifier1=RandomForestClassifier()
classifier1.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
y_pred=classifier1.predict(x_test)
cm=confusion_matrix(y_test,y_pred)
print(cm)
accuracy=accuracy_score(y_test,y_pred)
print(accuracy)
# Out:
# [[ 17   3   3   0   0   0   1]
#  [  0 175   1   2   1  10   0]
#  [  0   1 244  15   0   3   0]
#  [  0   0   3 389   0   6   3]
#  [  0   1   2   1 105   1   1]
#  [  0   6   3   8   0 539   0]
#  [  0   0   2   7   1   3 233]]
# 0.9508379888268157

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# %%
df.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
df_minmax_scaled=scaler.fit_transform(df)

# %%
input_dim=df_minmax_scaled.shape[1]

# %%
encoding_dim = 8
input_layer = layers.Input(shape=(input_dim,))
encoded = layers.Dense(encoding_dim, activation='relu')(input_layer)
decoded = layers.Dense(input_dim, activation='sigmoid')(encoded)
autoencoder = models.Model(inputs=input_layer, outputs=decoded)
autoencoder.compile(optimizer='adam', loss='mse')
autoencoder.fit(
    df_minmax_scaled, df_minmax_scaled,
    epochs=50,
    batch_size=32,
    validation_split=0.2,
    verbose=1
)
# Out:
# Epoch 1/50
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.1771 - val_loss: 0.0777
# Epoch 2/50
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0558 - val_loss: 0.0377
# Epoch 3/50
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0295 - val_loss: 0.0259
# Epoch 4/50
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0205 - val_loss: 0.0201
# Epoch 5/50
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0160 - val_loss: 0.0166
# Epoch 6/50
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0123 - val_loss: 0.0133
# Epoch 7/50
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0093 - val_loss: 0.0115
# Epoch 8/50
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0075 - val_loss: 0.0105
# Epoch 9/50
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0071 - val_loss: 0.0096
# Epoch 10/50
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0062 - val_loss: 0.0088
# Epoch 11/50
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0056 - val_loss: 0.0081
# ...

# %%
encoder = models.Model(inputs=input_layer, outputs=encoded)
latent_features = encoder.predict(df_minmax_scaled)
encoded_df = pd.DataFrame(latent_features, columns=[f'feature_{i}' for i in range(encoding_dim)])

print("Latent Features (Sample):")
print(encoded_df.head())
# Out:
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Latent Features (Sample):
#    feature_0  feature_1  feature_2  feature_3  feature_4  feature_5  \
# 0   1.018031   1.131759   0.977256   2.567330   1.394870   1.052306
# 1   0.497416   0.808955   1.134349   2.446996   1.654965   1.422228
# 2   3.695505   1.129055   0.527734   2.612086   1.939152   2.603470
# 3   0.730766   1.076575   0.676858   2.522813   1.840975   1.115105
# 4   1.184437   0.956691   1.169508   2.844653   1.448721   1.351260
#
#    feature_6  feature_7
# 0   1.822620        0.0
# 1   1.380450        0.0
# 2   1.268459        0.0
# 3   1.362946        0.0
# 4   1.621824        0.0

# %%
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans_2 = KMeans(n_clusters = i, init = 'k-means++',n_init=10, random_state = 42)
    kmeans_2.fit(encoded_df)
    wcss.append(kmeans_2.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
kmeans_2 = KMeans(n_clusters = 4, init = 'k-means++',n_init=10, random_state = 42)
ymeans=kmeans_2.fit_predict(df_minmax_scaled)

# %%
cluster_centers_2= pd.DataFrame(data = kmeans_2.cluster_centers_, columns = [df.columns])
cluster_centers_2
# Out:
#     BALANCE BALANCE_FREQUENCY PURCHASES ONEOFF_PURCHASES  \
# 0  0.100182          0.974591  0.066240         0.059509
# 1  0.061942          0.929710  0.022268         0.006873
# 2  0.114725          0.966243  0.005955         0.005804
# 3  0.008048          0.380567  0.007145         0.005779
#
#   INSTALLMENTS_PURCHASES CASH_ADVANCE PURCHASES_FREQUENCY  \
# 0               0.036566     0.013800            0.901399
# 1               0.036112     0.011043            0.883255
# 2               0.002471     0.033922            0.136549
# 3               0.005114     0.010775            0.208995
#
#   ONEOFF_PURCHASES_FREQUENCY PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                   0.805797                         0.491256
# 1                   0.102362                         0.832337
# 2                   0.087054                         0.050022
# 3                   0.073897                         0.127023
#
# ...

# %%
cluster_centers_2 = scaler.inverse_transform(cluster_centers_2)
cluster_centers_2 = pd.DataFrame(data = cluster_centers_2, columns = [df.columns])
cluster_centers_2
# Out:
#        BALANCE BALANCE_FREQUENCY    PURCHASES ONEOFF_PURCHASES  \
# 0  1907.788030          0.974591  3248.394294      2425.655021
# 1  1179.575654          0.929710  1091.990584       280.140808
# 2  2184.725867          0.966243   292.021239       236.587224
# 3   153.256122          0.380567   350.388003       235.561881
#
#   INSTALLMENTS_PURCHASES CASH_ADVANCE PURCHASES_FREQUENCY  \
# 0             822.739272   650.497493            0.901399
# 1             812.517168   520.529763            0.883255
# 2              55.597498  1598.975143            0.136549
# 3             115.071007   507.900330            0.208995
#
#   ONEOFF_PURCHASES_FREQUENCY PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                   0.805797                         0.491256
# 1                   0.102362                         0.832337
# 2                   0.087054                         0.050022
# 3                   0.073897                         0.127023
#
# ...

# %%
labels_1=kmeans_2.labels_
df_cluster_1 = pd.concat([df, pd.DataFrame({'cluster':labels})], axis = 1)
df_cluster_1.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# ...

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 2)
df_minmax_scaled = pca.fit_transform(df_minmax_scaled)

# %%
pca_creditdf_2=pd.DataFrame(df_minmax_scaled,columns=["pca1","pca2"])
pca_creditdf_2.head()
# Out:
#        pca1      pca2
# 0 -0.482156 -0.097600
# 1 -0.608582 -0.019426
# 2  0.304500  0.920937
# 3 -0.588628 -0.005657
# 4 -0.554347  0.053027

# %%
pca_creditdf_2=pd.concat([pca_creditdf_2,pd.DataFrame({"cluster":labels_1})],axis=1)
pca_creditdf_2.head()
# Out:
#        pca1      pca2  cluster
# 0 -0.482156 -0.097600        2
# 1 -0.608582 -0.019426        2
# 2  0.304500  0.920937        0
# 3 -0.588628 -0.005657        2
# 4 -0.554347  0.053027        2

# %%
plt.figure(figsize=(10,10))
ax = sns.scatterplot(x="pca1", y="pca2", hue = "cluster", data = pca_creditdf_2, palette =['red','green','blue','pink','yellow','gray','purple', 'black'])
plt.show()
# Out:
# <ipython-input-204-c73cc5d7cf00>:2: UserWarning: The palette list has more values (8) than needed (4), which may not be intended.
#   ax = sns.scatterplot(x="pca1", y="pca2", hue = "cluster", data = pca_creditdf_2, palette =['red','green','blue','pink','yellow','gray','purple', 'black'])
